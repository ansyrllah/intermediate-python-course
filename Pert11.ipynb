# %%
import numpy as np
import pandas as pd

# %%
data = new_df = pd.DataFrame({'col_a': [1,2,4,1, np.nan, np.nan, 5],
                       'col_b': [3,7, np.nan, 9, None, 5, 8],
                       'col_c': ['a', '?', 'x', 'y', '--', np.nan, 'r'],
                       'col_d': [True, True, np.nan, None, False, True, False]})
data
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     ?   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN    --  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
data.isna()
# Out:
#    col_a  col_b  col_c  col_d
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False   True  False   True
# 3  False  False  False   True
# 4   True   True  False  False
# 5   True  False   True  False
# 6  False  False  False  False

# %%
data.isna().sum()
# Out:
# col_a    2
# col_b    2
# col_c    1
# col_d    2
# dtype: int64

# %%
data.isna().any()
# Out:
# col_a    True
# col_b    True
# col_c    True
# col_d    True
# dtype: bool

# %%
data.to_csv('my_data')

# %%
missing_value = ['?', '--']

# %%
df2 = pd.read_csv('my_data.csv', na_values=missing_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2cc84e520507> in <module>
# ----> 1 df2 = pd.read_csv('my_data.csv', na_values=missing_values)
#
# NameError: name 'missing_values' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2068723f1203> in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
data.dropna
# Out:
# <bound method DataFrame.dropna of    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     ?   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN    --  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False>

# %%
df3 = data.replace({'?': np.nan, '--': np.nan})

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df3.dropna(axis=0, how='all', inplace=True)

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df5 = df3.ffill(0)

# %%
df5
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     a   True
# 2    4.0    7.0     x   True
# 3    1.0    9.0     y   True
# 4    1.0    9.0     y  False
# 5    1.0    5.0     y   True
# 6    5.0    8.0     r  False

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df3.iloc[:, 0] = df3.iloc[:, 0].fillna(df3.iloc[:, 0].mean())

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    2.6    NaN   NaN  False
# 5    2.6    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
